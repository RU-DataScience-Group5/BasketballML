# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
mvp = pd.read_csv("Data/MVP.csv")
# mvp = mvp.drop("Unnamed: 0", axis=1)
mvp
# Out:
#     Rank               Player  Age   Tm  First  Pts Won  Pts Max  Share   G  \
# 0      1  Kareem Abdul-Jabbar   32  LAL  147.0    147.0      221  0.665  82
# 1      2        Julius Erving   29  PHI   31.5     31.5      221  0.143  78
# 2      3        George Gervin   27  SAS   19.0     19.0      221  0.086  78
# 3      4           Larry Bird   23  BOS   15.0     15.0      221  0.068  82
# 4     5T       Tiny Archibald   31  BOS    2.0      2.0      221  0.009  80
# ..   ...                  ...  ...  ...    ...      ...      ...    ...  ..
# 653    8         Kevin Durant   30  GSW    0.0     25.0     1010  0.025  78
# 654    9        Kawhi Leonard   27  TOR    0.0     13.0     1010  0.013  60
# 655   10    Russell Westbrook   30  OKC    0.0      8.0     1010  0.008  73
# 656  11T          Rudy Gobert   26  UTA    0.0      1.0     1010  0.001  81
# 657  11T         LeBron James   34  LAL    0.0      1.0     1010  0.001  55
#
# ...

# %%
mvp.dtypes
# Out:
# Rank        object
# Player      object
# Age          int64
# Tm          object
# First      float64
# Pts Won    float64
# Pts Max      int64
# Share      float64
# G            int64
# MP         float64
# PTS        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# FG%        float64
# 3P%        float64
# FT%        float64
# WS         float64
# WS/48      float64
# season      object
# dtype: object

# %%
mvp.astype({"Age": "float64"}).dtypes
# Out:
# Rank        object
# Player      object
# Age        float64
# Tm          object
# First      float64
# Pts Won    float64
# Pts Max      int64
# Share      float64
# G            int64
# MP         float64
# PTS        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# FG%        float64
# 3P%        float64
# FT%        float64
# WS         float64
# WS/48      float64
# season      object
# dtype: object

# %%
mean_mvp = mvp["WS"].mean()
print(f"Average Win Share by MVP candidate: {mean_mvp}")
# Out:
# Average Win Share by MVP candidate: 10.69984802431611

# %%
X = mvp.drop(["Rank", "Player", "Tm", "First", "Pts Won", "Pts Max", "Share", "WS", "season"], axis=1)
y = mvp["WS"]
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (658, 12) (658,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

predicted = model.predict(X_test)

# mean squared error and r-squared score
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"MSE: {mse}")
print(f"R2: {r2}")
# Out:
# MSE: 0.15256068330426462
# R2: 0.9841245251632774
