# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# %%
mvp = pd.read_csv("Data/AllPlayerData.csv")
mvp
# Out:
#                     Player   PlayerID Pos   Season        Table Name   Tm  \
# 0       Mahmoud Abdul-Rauf  abdulma02  PG  2000-01  players00-01.csv  VAN
# 1        Tariq Abdul-Wahad  abdulta01  SG  2000-01  players00-01.csv  DEN
# 2      Shareef Abdur-Rahim  abdursh01  SF  2000-01  players00-01.csv  VAN
# 3           Cory Alexander  alexaco01  PG  2000-01  players00-01.csv  ORL
# 4       Courtney Alexander  alexaco02  PG  2000-01  players00-01.csv  TOT
# ...                    ...        ...  ..      ...               ...  ...
# 11713       Thaddeus Young  youngth01  PF  2019-20  players19-20.csv  CHI
# 11714           Trae Young  youngtr01  PG  2019-20  players19-20.csv  ATL
# 11715          Cody Zeller  zelleco01   C  2019-20  players19-20.csv  CHO
# 11716           Ante Žižić  zizican01   C  2019-20  players19-20.csv  CLE
# 11717          Ivica Zubac  zubaciv01   C  2019-20  players19-20.csv  LAC
#
#         2P    2P%   2PA   3P  ...  GS    MP  ORB   PF   PTS   Rk  STL  TOV  \
# 0      116  0.500   232    4  ...   0   486    5   50   266    1    9   26
# 1       39  0.386   101    4  ...  12   420   14   54   111    2   14   34
# 2      592  0.487  1216   12  ...  81  3241  175  238  1663    3   90  231
# 3       14  0.350    40    4  ...   0   227    0   29    52    4   16   25
# 4      222  0.421   527   17  ...  24  1382   42  139   618    5   45   75
# ...    ...    ...   ...  ...  ...  ..   ...  ...  ...   ...  ...  ...  ...
# 11713  190  0.501   379   79  ...  16  1591   94  134   659  516   92  102
# 11714  341  0.501   681  205  ...  60  2120   32  104  1778  517   65  289
# 11715  233  0.577   404   18  ...  39  1341  160  140   642  518   40   75
# 11716   41  0.569    72    0  ...   0   221   18   27    96  519    7   10
# 11717  203  0.602   337    0  ...  63  1172  167  150   513  520   14   55
#
#        TRB  MVP
# 0       25    0
# 1       59    0
# 2      735    0
# 3       25    0
# 4      143    0
# ...    ...  ...
# 11713  315    0
# 11714  255    0
# 11715  411    0
# 11716   66    0
# 11717  464    0
#
# [11718 rows x 34 columns]

# %%
target = mvp["MVP"]
target_names = ["winner", "loser"]

# %%
data = mvp.drop(["Player", "PlayerID", "Pos", "Season", "Table Name", "Tm", "Rk", "MVP"], axis=1)
feature_names = data.columns
data.head()
# Out:
#     2P    2P%   2PA  3P    3P%  3PA  Age  AST  BLK  DRB  ...  FTA   G  GS  \
# 0  116  0.500   232   4  0.286   14   31   76    1   20  ...   29  41   0
# 1   39  0.386   101   4  0.400   10   26   22   13   45  ...   36  29  12
# 2  592  0.487  1216  12  0.188   64   24  250   77  560  ...  531  81  81
# 3   14  0.350    40   4  0.250   16   27   36    0   25  ...   18  26   0
# 4  222  0.421   527  17  0.370   46   23   62    5  101  ...  150  65  24
#
#      MP  ORB   PF   PTS  STL  TOV  TRB
# 0   486    5   50   266    9   26   25
# 1   420   14   54   111   14   34   59
# 2  3241  175  238  1663   90  231  735
# 3   227    0   29    52   16   25   25
# 4  1382   42  139   618   45   75  143
#
# [5 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9969283276450512

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9976109215017065

# %%
importances = rf.feature_importances_
importances
# Out:
# array([0.04835561, 0.02848465, 0.04400633, 0.03568412, 0.03806768,
#        0.02626263, 0.01348441, 0.0596784 , 0.02790861, 0.07104156,
#        0.0351106 , 0.048732  , 0.03696224, 0.03174041, 0.05101662,
#        0.03810875, 0.03192914, 0.02563585, 0.02547343, 0.03124377,
#        0.02777663, 0.08187177, 0.05555947, 0.03158242, 0.02774493,
#        0.02653797])

# %%
sorted(zip(importances, feature_names), reverse=True)
# Out:
# [(0.08187177279468351, 'PF'),
#  (0.07104155653487405, 'DRB'),
#  (0.05967840113686173, 'AST'),
#  (0.05555946518971558, 'PTS'),
#  (0.0510166236684463, 'FT'),
#  (0.04873199876800296, 'FG'),
#  (0.048355609510410985, '2P'),
#  (0.0440063254944686, '2PA'),
#  (0.03810875446341874, 'FT%'),
#  (0.03806768290717481, '3P%'),
#  (0.03696223558914875, 'FG%'),
#  (0.03568411985942914, '3P'),
#  (0.03511060140688061, 'eFG%'),
#  (0.031929143583092165, 'FTA'),
#  (0.03174040648511829, 'FGA'),
#  (0.03158242333946462, 'STL'),
#  (0.031243768491241795, 'MP'),
#  (0.028484648368142483, '2P%'),
#  (0.02790861003245642, 'BLK'),
#  (0.027776625788647324, 'ORB'),
#  (0.027744934733012695, 'TOV'),
#  (0.026537974429922864, 'TRB'),
#  (0.026262629731318307, '3PA'),
#  (0.025635847417733816, 'G'),
#  (0.025473434253940188, 'GS'),
#  (0.013484406022393243, 'Age')]
