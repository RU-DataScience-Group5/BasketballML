# %%
# Dependencies
import pandas as pd
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
stats = pd.read_csv("Data/AdvancedStats.csv")
# mvp = mvp.drop("Table Name", axis = 1)
stats["PlayerName"] = stats["Player"].str.split("\\", n=1, expand=True)[0]
stats["PlayerID"] = stats["Player"].str.split("\\", n=1, expand=True)[1]
stats.drop("Player", axis = 1)
stats.fillna(0)
# Out:
#         Rk                    Player Pos  Age   Tm   G    MP   PER    TS%  \
# 0        1      Mark Acres\acresma01   C   27  ORL  80  1691   8.3  0.536
# 1        2   Michael Adams\adamsmi01  PG   27  DEN  79  2690  15.4  0.542
# 2        3    Mark Aguirre\aguirma01  SF   30  DET  78  2005  15.8  0.544
# 3        4     Danny Ainge\aingeda01  PG   30  SAC  75  2727  16.1  0.528
# 4        5     Mark Alarie\alarima01  PF   26  WSB  82  1893  14.1  0.510
# ...    ...                       ...  ..  ...  ...  ..   ...   ...    ...
# 17124  518  Thaddeus Young\youngth01  PF   31  CHI  64  1591  13.3  0.521
# 17125  519      Trae Young\youngtr01  PG   21  ATL  60  2120  23.9  0.595
# 17126  520     Cody Zeller\zelleco01   C   27  CHO  58  1341  18.8  0.576
# 17127  521      Ante Žižić\zizican01   C   23  CLE  22   221  16.4  0.597
# 17128  522     Ivica Zubac\zubaciv01   C   22  LAC  66  1196  20.7  0.638
#
#         3PAr  ...  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP   season  \
# 0      0.014  ...  0.6  1.6  0.047  -3.1  -0.6 -3.7  -0.7  1989-90
# 1      0.437  ...  2.5  6.9  0.124   1.8  -0.1  1.8   2.6  1989-90
# 2      0.104  ...  2.5  5.7  0.136   1.0   0.0  1.0   1.5  1989-90
# 3      0.250  ...  2.1  4.8  0.085   1.2  -0.1  1.1   2.1  1989-90
# 4      0.062  ...  1.6  3.1  0.079  -0.6  -0.7 -1.3   0.3  1989-90
# ...      ...  ...  ...  ...    ...   ...   ...  ...   ...      ...
# 17124  0.369  ...  2.1  1.9  0.058  -1.4   0.2 -1.1   0.4  2019-20
# 17125  0.455  ...  0.5  5.9  0.133   6.3  -2.3  4.0   3.2  2019-20
# 17126  0.157  ...  1.3  3.6  0.129   0.2  -0.8 -0.6   0.5  2019-20
# 17127  0.000  ...  0.2  0.5  0.106  -1.7  -1.5 -3.2  -0.1  2019-20
# 17128  0.006  ...  2.1  5.7  0.229   1.3   1.0  2.4   1.3  2019-20
#
#            PlayerName   PlayerID
# 0          Mark Acres  acresma01
# 1       Michael Adams  adamsmi01
# 2        Mark Aguirre  aguirma01
# 3         Danny Ainge  aingeda01
# 4         Mark Alarie  alarima01
# ...               ...        ...
# 17124  Thaddeus Young  youngth01
# 17125      Trae Young  youngtr01
# 17126     Cody Zeller  zelleco01
# 17127      Ante Žižić  zizican01
# 17128     Ivica Zubac  zubaciv01
#
# [17129 rows x 30 columns]

# %%
cols = stats.columns.tolist()
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['PlayerID',
#  'Rk',
#  'Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'MP',
#  'PER',
#  'TS%',
#  '3PAr',
#  'FTr',
#  'ORB%',
#  'DRB%',
#  'TRB%',
#  'AST%',
#  'STL%',
#  'BLK%',
#  'TOV%',
#  'USG%',
#  'OWS',
#  'DWS',
#  'WS',
#  'WS/48',
#  'OBPM',
#  'DBPM',
#  'BPM',
#  'VORP',
#  'season',
#  'PlayerName']

# %%
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['PlayerName',
#  'PlayerID',
#  'Rk',
#  'Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'MP',
#  'PER',
#  'TS%',
#  '3PAr',
#  'FTr',
#  'ORB%',
#  'DRB%',
#  'TRB%',
#  'AST%',
#  'STL%',
#  'BLK%',
#  'TOV%',
#  'USG%',
#  'OWS',
#  'DWS',
#  'WS',
#  'WS/48',
#  'OBPM',
#  'DBPM',
#  'BPM',
#  'VORP',
#  'season']

# %%
ws = stats.iloc[:,23]
per = mvp.iloc[:,10]
plt.scatter(ws, per)
plt.xlabel("Win Shares")
plt.ylabel("PER")
plt.show

correlation = st.pearsonr(ws, per)
print(f"Correlation between Win Shares and PER is {correlation[0]}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-31d70b2a45b2> in <module>
#       6 plt.show
#       7
# ----> 8 correlation = st.pearsonr(ws, per)
#       9 print(f"Correlation between Win Shares and PER is {correlation[0]}")
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonAdv\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3866     # [-5e210, 5e210, 3e200, -3e200]
#    3867     normxm = linalg.norm(xm)
# -> 3868     normym = linalg.norm(ym)
#    3869
#    3870     threshold = 1e-13
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonAdv\lib\site-packages\scipy\linalg\misc.py in norm(a, ord, axis, keepdims, check_finite)
#     138     # Differs from numpy only in non-finite handling and the use of blas.
#     139     if check_finite:
# --> 140         a = np.asarray_chkfinite(a)
#     141     else:
#     142         a = np.asarray(a)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonAdv\lib\site-packages\numpy\lib\function_base.py in asarray_chkfinite(a, dtype, order)
#     497     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     498         raise ValueError(
# --> 499             "array must not contain infs or NaNs")
#     500     return a
#     501
#
# ValueError: array must not contain infs or NaNs

# %%
minutes = mvp.iloc[:,24]
efg = mvp.iloc[:,15]
plt.scatter(minutes,efg)
plt.xlabel("Minutes")
plt.ylabel("eFG%")
plt.show

correlation = st.pearsonr(minutes, efg)
print(f"Correlation between Minutes and eFG% is {correlation[0]}")
# Out:
# Correlation between Minutes and eFG% is 0.2935058853180998

# %%
minutes = mvp.iloc[:,24]
efg = mvp.iloc[:,15]
plt.scatter(minutes,efg)
plt.xlabel("Minutes")
plt.ylabel("eFG%")
plt.show

correlation = st.pearsonr(minutes, efg)
print(f"Correlation between Minutes and eFG% is {correlation[0]}")
